# %%
import pandas as pd
houses = pd.read_csv('./casas_asturias.csv', sep=';')

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1960 entries, 0 to 1959
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Id del anuncio                1960 non-null   int64
#  1   Título                        1960 non-null   object
#  2   Tipo de inmueble              1960 non-null   object
#  3   Tipo de vendedor              1960 non-null   object
#  4   Habitaciones                  1960 non-null   int64
#  5   Barrio                        1960 non-null   object
#  6   Municipio                     1960 non-null   object
#  7   Euros/m2                      1960 non-null   int64
#  8   Metros cuadrados construidos  1960 non-null   object
#  9   Obra nueva (Sí/No)            1960 non-null   object
#  10  Parking (Sí/No)               1960 non-null   object
#  11  Jardín (Sí/No)                1960 non-null   object
# ...

# %%
houses.sample(5)
# Out:
#       Id del anuncio                                          Título  \
# 923        105788557                                            Piso
# 1860       106139602  Casa independiente en calle Ortega y Gasset, 9
# 24          99565268                    Piso en calle Charles Darwin
# 1007       105891991              Casa independiente en As-219, 4 -7
# 675        106983769      Casa independiente en calle de San Lorenzo
#
#      Tipo de inmueble Tipo de vendedor  Habitaciones            Barrio  \
# 923              Piso      Profesional             3                 -
# 1860           Chalet      Profesional             7          Vallobín
# 24               Piso      Profesional             4  Plaza de América
# 1007           Chalet      Profesional             6                 -
# 675            Chalet      Profesional             4                 -
#
#            Municipio  Euros/m2 Metros cuadrados construidos  \
# ...
